# %%
import pandas as pd

# %%
df=pd.read_table('Data\TweetsCOV19.tsv',error_bad_lines=False,warn_bad_lines=True,header=None)
# Out:
# b'Skipping line 3609902: expected 12 fields, saw 13\n'

# %%
df2=pd.read_table('Data\TweetsCOV19_052020.tsv',error_bad_lines=False,warn_bad_lines=True,header=None)

# %%
df3=pd.read_table('Data\TweetsCOV19_3.tsv',error_bad_lines=False,warn_bad_lines=True,header=None)
# Out:
# b'Skipping line 9885107: expected 12 fields, saw 13\n'

# %%
dfcomb=df.append(df2)

# %%
dfcomb=dfcomb.append(df3)

# %%
dfcomb.columns=['Tweet_Id','Username','Timestamp','#Followers','#Friends','#Retweets','#Favorites',"Entities",'Sentiment','Mentions',"Hashtags","URLs"]

# %%
dfcomb.reset_index().to_feather('Data\here.ftr')

# %%
import seaborn as sns

# %%
corr=dfcomb.corr()

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_e83df_ th {
#           font-size: 7pt;
#     }    #T_e83df_ td {
#           padding: 0em 0em;
#     }    #T_e83df_ th:hover {
#           font-size: 12pt;
#     }    #T_e83df_ tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_e83df_row0_col0,#T_e83df_row1_col1,#T_e83df_row2_col2,#T_e83df_row3_col3,#T_e83df_row4_col4{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_e83df_row0_col1,#T_e83df_row0_col2,#T_e83df_row0_col3,#T_e83df_row1_col0,#T_e83df_row2_col0,#T_e83df_row3_col0,#T_e83df_row4_col0{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_e83df_row0_col4{
#             background-color:  #d73d5c;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(np.random.rand(7,20))

df.plot(subplots=True)

plt.show()
